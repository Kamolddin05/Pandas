# %%
""" Introducing Pandas Objects """
# Out:
# ' Introducing Pandas Objects '

# %%
import numpy as np
import pandas as pd

# %%
# >>>---------------->> The Pandas Series Object <<---------------<<< #

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.values
# Out:
# array([0.25, 0.5 , 0.75, 1.  ])

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data[1]
# Out:
# np.float64(0.5)

# %%
data[1:3]
# Out:
# 1    0.50
# 2    0.75
# dtype: float64

# %%
s = pd.Series([10, 20, 30], index=["a", "b", "c"])
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# Series as generalized NumPy array #

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index = ["a", "b", "c", "d"])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data["a"]
# Out:
# np.float64(0.25)

# %%
data["a":"d"]
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index = [2, 5, 3, 7])
data
# Out:
# 2    0.25
# 5    0.50
# 3    0.75
# 7    1.00
# dtype: float64

# %%
data[3]
# Out:
# np.float64(0.75)

# %%
data[:]
# Out:
# 2    0.25
# 5    0.50
# 3    0.75
# 7    1.00
# dtype: float64

# %%
# Series as specialized dictionary

# %%
population_dict = {
    "California":38332521,
    "Texas":26448193,
    "New York":19651127,
    "Florida":19552860,
    "Illionis":12882135

}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illionis      12882135
# dtype: int64

# %%
population['California']
# Out:
# np.int64(38332521)

# %%
population['California' : 'Illionis']
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illionis      12882135
# dtype: int64

# %%
# Constructing Series objects

# %%
pd.Series([2, 4, 6])
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
pd.Series(5, index=[100, 200, 300])
# Out:
# 100    5
# 200    5
# 300    5
# dtype: int64

# %%
pd.Series({2: 'a', 1: 'b', 3: 'c'})
# Out:
# 2    a
# 1    b
# 3    c
# dtype: object

# %%
pd.Series({2: 'a', 1: 'b', 3: 'c'}, index=[3, 2])
# Out:
# 3    c
# 2    a
# dtype: object

# %%
# >>>-------------->> The Pandas DataFrame Object <<-----------------<<<

# %%
# DataFrame as a generalized NumPy array

# %%
area_dict = {
    'California': 423967,
    'Texas': 695662,
    'New York': 141297,
    'Florida': 170312,
    'Illinois': 149995
}

area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states = pd.DataFrame({
    "population":population,
    "are":area
})

states
# Out:
#             population       are
# California  38332521.0  423967.0
# Florida     19552860.0  170312.0
# Illinois           NaN  149995.0
# Illionis    12882135.0       NaN
# New York    19651127.0  141297.0
# Texas       26448193.0  695662.0

# %%
states.index
# Out:
# Index(['California', 'Florida', 'Illinois', 'Illionis', 'New York', 'Texas'], dtype='object')

# %%
states.values
# Out:
# array([[38332521.,   423967.],
#        [19552860.,   170312.],
#        [      nan,   149995.],
#        [12882135.,       nan],
#        [19651127.,   141297.],
#        [26448193.,   695662.]])

# %%
states.columns
# Out:
# Index(['population', 'are'], dtype='object')

# %%
population_dict = {
    "California":38332521,
    "Texas":26448193,
    "New York":19651127,
    "Florida":19552860,
    "Illionis":12882135

}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illionis      12882135
# dtype: int64

# %%
area_dict = {
    'California': 423967,
    'Texas': 695662,
    'New York': 141297,
    'Florida': 170312,
    'Illinois': 149995
}

area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states = pd.DataFrame({
    "population":population,
    "area":area
})

states
# Out:
#             population      area
# California  38332521.0  423967.0
# Florida     19552860.0  170312.0
# Illinois           NaN  149995.0
# Illionis    12882135.0       NaN
# New York    19651127.0  141297.0
# Texas       26448193.0  695662.0

# %%
name_age_dict = {
    "Kamoliddin":20,
    "Azizbek":20,
    "Diyorbek":19,
    "Fotima":19,
    "Izmir":18,
    "Alya":15,
    "Zakariyya":12,
    "Zubayr":10
}

age = pd.Series(name_age_dict)
age
# Out:
# Kamoliddin    20
# Azizbek       20
# Diyorbek      19
# Fotima        19
# Izmir         18
# Alya          15
# Zakariyya     12
# Zubayr        10
# dtype: int64

# %%
name_year_dict = {
    "Kamoliddin":2005,
    "Azizbek":2005,
    "Diyorbek":2006,
    "Fotima":2006,
    "Izmir":2007,
    "Alya":2009,
    "Zakariyya": 2013,
    "Zubayr": 15
}

year = pd.Series(name_year_dict)
year
# Out:
# Kamoliddin    2005
# Azizbek       2005
# Diyorbek      2006
# Fotima        2006
# Izmir         2007
# Alya          2009
# Zakariyya     2013
# Zubayr          15
# dtype: int64

# %%
df = pd.DataFrame({
    "year":year,
    "age":age
})
df
# Out:
#             year  age
# Kamoliddin  2005   20
# Azizbek     2005   20
# Diyorbek    2006   19
# Fotima      2006   19
# Izmir       2007   18
# Alya        2009   15
# Zakariyya   2013   12
# Zubayr        15   10

# %%
# DataFrame as specialized dictionary

# %%
area_dict = {
    'California': 423967,
    'Texas': 695662,
    'New York': 141297,
    'Florida': 170312,
    'Illinois': 149995
}

area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states['area']
# Out:
# California    423967.0
# Florida       170312.0
# Illinois      149995.0
# Illionis           NaN
# New York      141297.0
# Texas         695662.0
# Name: area, dtype: float64

# %%
# Constructing DataFrame objects

# %%
pd.DataFrame(population, columns= ["Population"])
# Out:
#             Population
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illionis      12882135

# %%
data = [{"a":i, "b":2 * i, } for i in range(3)]
pd.DataFrame(data)
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %%
pd.DataFrame([{"a":1, "b":2}, {"b":3, "c":4}])
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  4.0

# %%
pd.DataFrame([{"Kamoliddin": i, "Azizbek":2 * i, "Diyorbek": 3 * i} 
              for i in range(6)])
# Out:
#    Kamoliddin  Azizbek  Diyorbek
# 0           0        0         0
# 1           1        2         3
# 2           2        4         6
# 3           3        6         9
# 4           4        8        12
# 5           5       10        15

# %%
pd.DataFrame({"population":population, "area":area})
# Out:
#             population      area
# California  38332521.0  423967.0
# Florida     19552860.0  170312.0
# Illinois           NaN  149995.0
# Illionis    12882135.0       NaN
# New York    19651127.0  141297.0
# Texas       26448193.0  695662.0

# %%
pd.DataFrame(np.random.rand(3, 2), columns= ["for", "bar"], index = ["a", "b", "c"])
# Out:
#         for       bar
# a  0.268089  0.635329
# b  0.185297  0.739179
# c  0.274932  0.229873

# %%
A = np.zeros(3, dtype=[("A", "i8"), ("B", "f8")])
A
# Out:
# array([(0, 0.), (0, 0.), (0, 0.)], dtype=[('A', '<i8'), ('B', '<f8')])

# %%
pd.DataFrame(A)
# Out:
#    A    B
# 0  0  0.0
# 1  0  0.0
# 2  0  0.0

# %%
# >>>------------------>> The Pandas Index Object <<-----------------<<< #

# %%
ind = pd.Index([2, 3, 5, 7, 11])
ind
# Out:
# Index([2, 3, 5, 7, 11], dtype='int64')

# %%
ind[1]
# Out:
# np.int64(3)

# %%
ind[::2]
# Out:
# Index([2, 5, 11], dtype='int64')

# %%
print(ind.size, ind.shape, ind.ndim, ind.dtype)
# Out:
# 5 (5,) 1 int64

# %%
ind[1] = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 ind[1] = 0
#
# File c:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:5383, in Index.__setitem__(self, key, value)
#    5381 @final
#    5382 def __setitem__(self, key, value) -> None:
# -> 5383     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
indA = pd.Index([1, 3, 5, 7, 9])
indB = pd.Index([2, 3, 5, 7, 11])

# %%
indA & indB  # kesishma
# Out:
# Index([0, 3, 5, 7, 9], dtype='int64')

# %%
indA | indB  # birlashma
# Out:
# Index([3, 3, 5, 7, 11], dtype='int64')

# %%
indA ^ indB  # simmetrik farq
# Out:
# Index([3, 0, 0, 0, 2], dtype='int64')

# %%
indA.intersection(indB)
# Out:
# Index([3, 5, 7], dtype='int64')

# %% [markdown]
# ![{E3725D37-EC73-4F1A-831C-D524385DF54D}.png](attachment:{E3725D37-EC73-4F1A-831C-D524385DF54D}.png)

# %% [markdown]
# EXAMPLES (1 - 10)

# %% [markdown]
# ![{B5FA096E-7BCF-49F6-9A6D-251A32F19710}.png](attachment:{B5FA096E-7BCF-49F6-9A6D-251A32F19710}.png)

# %%
# 1

y= pd.Series([10, 20, 30, 40], index= ["w", "x", "y", "z"])
y
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
# 2
y["w": "x"]
# Out:
# w    10
# x    20
# dtype: int64

# %%
#3
b= pd.Series({"a":100, "b":200, "c":100})
b
# Out:
# a    100
# b    200
# c    100
# dtype: int64

# %%
#4
s = pd.Series([7, 8, 9], index= [10, 20, 30])
s
# Out:
# 10    7
# 20    8
# 30    9
# dtype: int64

# %%
#5
pop = pd.Series([100, 200, 300], index= ["A", "B", "C"])
area = pd.Series([50, 60, 70], index= ["A", "B", "C"])

df = pd.DataFrame({
    "population":pop,
    "area":area
})
df
# Out:
#    population  area
# A         100    50
# B         200    60
# C         300    70

# %%
#6
df_dict = pd.DataFrame([
    {"x":1, "y":2},
    {"x":3, "y":4},
    {"y":5, "z":6}
    ])
df_dict
# Out:
#      x  y    z
# 0  1.0  2  NaN
# 1  3.0  4  NaN
# 2  NaN  5  6.0

# %%
#7
pop = pd.Series([100, 200, 300], index= ["A", "B", "C"])
area = pd.Series([50, 60, 70], index= ["A", "B", "C"])

df = pd.DataFrame({
    "population":pop,
    "area":area
})

df1 = pd.DataFrame(df["population"])
df1
# Out:
#    population
# A         100
# B         200
# C         300

# %%
#8
pd.Index(df1["population"])
# Out:
# Index([100, 200, 300], dtype='int64', name='population')

# %%
#8.1
b= pd.Series({"a":100, "b":200, "c":100})
pd.Index(b)
# Out:
# Index([100, 200, 100], dtype='int64')

# %%
#9
indexA =pd.Index([1, 3, 5, 7])
indexB = pd.Index([3, 5, 7 ,9])

print(indexA & indexB,
indexA | indexB)
# Out:
# Index([1, 1, 5, 1], dtype='int64') Index([3, 7, 7, 15], dtype='int64')

# %%
index = pd.Series( [12, 13, 14], index= [10, 20, 30])
index[20] == 100
index
# Out:
# 10    12
# 20    13
# 30    14
# dtype: int64
