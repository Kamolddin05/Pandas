# %%
import numpy as np
python_list = [3, 4, 5, 6, 7]
arr = np.array(python_list)
arr
# Out:
# array([3, 4, 5, 6, 7])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
from matplotlib import pyplot as plt
plt.scatter(np.arange(-3, 4),
            np.arange(0, 7))
plt.show()
