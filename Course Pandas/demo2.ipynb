# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
df["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# Name: Age, Length: 887, dtype: bool

# %%
df["Age"].isnull().count()
# Out:
# np.int64(887)

# %%
df1 = pd.read_csv("synthetic_dataset.csv")
df1.head()
# Out:
#   Category   Price    Rating         Stock  Discount
# 0      NaN  5548.0  1.870322           NaN       0.0
# 1      NaN  3045.0  4.757798           NaN      38.0
# 2      NaN  4004.0       NaN      In Stock       0.0
# 3      NaN  4808.0  1.492085           NaN      33.0
# 4      NaN  1817.0       NaN  Out of Stock      23.0

# %%
df1["Category"].isnull().sum()
# Out:
# np.int64(2748)

# %%
df1["Category"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4362 entries, 0 to 4361
# Series name: Category
# Non-Null Count  Dtype
# --------------  -----
# 1614 non-null   object
# dtypes: object(1)
# memory usage: 34.2+ KB

# %%
a=df1["Rating"].isnull().sum()
a
# Out:
# np.int64(2050)

# %%
df1["Stock"].isnull().sum()
# Out:
# np.int64(1352)

# %%
df2 = pd.read_csv("car_prices.csv")
df2.head()
# Out:
#    id    brand          model  model_year  milage fuel_type  \
# 0   0     Ford   F-150 Lariat        2018   74349  Gasoline
# 1   1      BMW          335 i        2007   80000  Gasoline
# 2   2   Jaguar      XF Luxury        2009   91491  Gasoline
# 3   3      BMW   X7 xDrive40i        2022    2437    Hybrid
# 4   4  Pontiac  Firebird Base        2001  111000  Gasoline
#
#                                               engine  \
# 0      375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1  300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 3  335.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 4      200.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col       accident clean_title  \
# 0                    10-Speed A/T    Blue    Gray  None reported         Yes
# 1                     6-Speed M/T   Black   Black  None reported         Yes
# ...

# %%
df2["milage"].between(100_000, 70_000)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54268    False
# 54269    False
# 54270    False
# 54271    False
# 54272    False
# Name: milage, Length: 54273, dtype: bool

# %%
df2[df2["milage"].between(70_000, 100_000)]
# Out:
#           id      brand                                     model  model_year  \
# 0          0       Ford                              F-150 Lariat        2018
# 1          1        BMW                                     335 i        2007
# 2          2     Jaguar                                 XF Luxury        2009
# 8          8       Audi                      A3 2.0T Tech Premium        2016
# 11        11  Chevrolet                             Tahoe Premier        2017
# ...      ...        ...                                       ...         ...
# 54252  54252       Land  Rover Range Rover Sport Supercharged HSE        2015
# 54258  54258        RAM                             1500 Longhorn        2019
# 54261  54261     Toyota                             Highlander SE        2017
# 54262  54262       Jeep                     Grand Cherokee Laredo        2011
# 54269  54269       Audi                           A4 2.0T Premium        2015
#
#        milage      fuel_type  \
# ...

# %%
df2[df2["model_year"].isin([2018])].sort_values("price")
# Out:
#           id          brand                              model  model_year  \
# 22020  22020           Audi                   Q7 3.0T Prestige        2018
# 46348  46348          Volvo                   XC90 T6 Momentum        2018
# 31788  31788          Volvo                   XC90 T6 Momentum        2018
# 223      223           Audi                    A3 2.0T Premium        2018
# 5151    5151  Mercedes-Benz               S-Class S 560 4MATIC        2018
# ...      ...            ...                                ...         ...
# 32223  32223    Rolls-Royce                            Phantom        2018
# 39741  39741            BMW                              M3 CS        2018
# 13385  13385  Mercedes-Benz  AMG GLE AMG GLE 63 S-Model 4MATIC        2018
# 42779  42779    Lamborghini                        570S Spider        2018
# 19606  19606         Toyota                     Tacoma TRD Pro        2018
#
# ...
